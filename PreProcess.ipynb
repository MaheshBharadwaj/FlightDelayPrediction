# %%
import pandas as pd
import json

# %%
f = open('./WeatherData/ATL/2016-1.json')
js = json.load(f)
df = pd.DataFrame(js['data']['weather'])
df
# Out:
#    mintempC maxtempF sunHour mintempF maxtempC  \
# 0         5       51     7.5       42       11
# 1         2       48     9.0       35        9
# 2         3       51     7.5       38       11
# 3        -1       46     9.5       31        8
# 4         1       43    10.0       33        6
# 5        -2       47     9.5       28        9
# 6         3       52     7.5       38       11
# 7         8       55     7.5       47       13
# 8        10       52     7.5       50       11
# 9         3       41     7.5       38        5
# 10       -3       43    10.0       26        6
# 11        3       49    10.0       38        9
# 12       -4       48    10.0       25        9
# 13        1       60     9.8       34       16
# 14        3       50     8.3       38       10
# 15        6       53     8.3       43       12
# 16        5       47     9.0       40        9
# 17        0       35    10.0       31        2
# 18       -5       38    10.0       23        3
# ...
